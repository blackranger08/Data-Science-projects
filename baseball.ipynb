# %% [markdown]
# # Problem Statement:
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# -- Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, and Errors
#
# -- Output: Number of predicted wins (W)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("bball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
#checking shape
df.shape
# Out:
# (30, 17)

# %%
#there are 30 rows and 17 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
#there is one float column and no object columns

# %%
#exploring data
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
#describing data
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
# The minimum number of predicted win is 63 and max is 100
#the maximum homeruns is 232 and min is 100
#the data seems to be normally distributed
#there is skewness in some columns

# %%
#checking for unique values in each columns
df.apply(lambda x:len(x.unique()))
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %%
#checking for null values
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
#univariate analysis
#ploting 
fig, ax=plt.subplots(ncols=2,nrows=9, figsize=(20,20))
index=0
ax=ax.flatten()
for col, value in df.items():
    if col != "type":
        sns.distplot(value, ax=ax[index])
        index+=1
plt.tight_layout(pad=0.5,w_pad=0.7,h_pad=5.0)

# %%
#sv,cg and h are right skewed, 
#majority of columns follows normal distribution
#There are outliers in some columns

# %%
#Bivarriate analysis

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
#W/R
plt.figure(figsize=(7,5))
sns.barplot(x="W", y="R",data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='R'>

# %%
#the r is lossley correlated with w.
#with the increase in r, w increase also, 
#however it is not a continus pattern

# %%
plt.figure(figsize=(7,5))
sns.barplot(x="W", y="AB",data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='AB'>

# %%
#AB is lossely correlated with w.
#no trend can be seen with the increase and decresse of the value

# %%
plt.figure(figsize=(7,5))
sns.barplot(x="W", y="H",data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='H'>

# %%
#H is lossely correlated with w.
#no trend can be seen with the increase and decresse of the value

# %%
plt.figure(figsize=(7,5))
sns.barplot(x="W", y="2B",data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='2B'>

# %%
## is incresing with the increase in 2b

# %%
plt.figure(figsize=(7,5))
sns.barplot(x="W", y="3B",data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='3B'>

# %%
#3b shows no pattern with the w

# %%
plt.figure(figsize=(7,5))
sns.barplot(x="W", y="HR",data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='HR'>

# %%
#with the increase in HR, w is also increasing

# %%
plt.figure(figsize=(7,5))
sns.barplot(x="W", y="BB",data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='BB'>

# %%
#with the increase in EB, w is also increasing

# %%
plt.figure(figsize=(7,5))
sns.barplot(x="W", y="SO",data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='SO'>

# %%
#with the increse in so there is a slight increase in w also

# %%
plt.figure(figsize=(7,5))
sns.barplot(x="W", y="SB",data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='SB'>

# %%
#w is incresing as the value of sb is goig down
#it is negatively correlated

# %%
plt.figure(figsize=(7,5))
sns.barplot(x="W", y="RA",data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='RA'>

# %%
#w is incresing as the value of RA is goig down
#it is negatively correlated

# %%
plt.figure(figsize=(7,5))
sns.barplot(x="W", y="ER",data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='ER'>

# %%
#w is incresing as the value of RA is goig down
#it is negatively correlated

# %%
plt.figure(figsize=(7,5))
sns.barplot(x="W", y="ERA",data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='ERA'>

# %%
#w is incresing as the value of ERA is goig down
#it is negatively correlated

# %%
plt.figure(figsize=(7,5))
sns.barplot(x="W", y="CG",data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='CG'>

# %%
#With the increase in cg the value of w is incresing
#it is lossely positive correlated

# %%
plt.figure(figsize=(7,5))
sns.barplot(x="W", y="SHO",data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='SHO'>

# %%
#With the increase in SHO the value of w is incresing

# %%
plt.figure(figsize=(7,5))
sns.barplot(x="W", y="SV",data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='SV'>

# %%
#With the increase in SV the value of w is incresing
#it is shoing a linear relation

# %%
plt.figure(figsize=(7,5))
sns.barplot(x="W", y="E",data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='E'>

# %%
#E is loosely corelated with w

# %%
#checking correlation
plt.figure(figsize=(15,10))
corr = df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
#a lot of independent variable is correlated with each other
# we will check for multicolinearity
#ERA,ER,RA is strongly correlated with #

# %%
#ploting boxplot  for outliers
fig, ax=plt.subplots(ncols=2,nrows=9, figsize=(20,20))
index=0
ax=ax.flatten()
for col, value in df.items():
    if col != "type":
        sns.boxplot(value, ax=ax[index])
        index+=1
plt.tight_layout(pad=0.5,w_pad=0.7,h_pad=5.0)

# %%
#there are outliers in some columns
#using IQR method to replace outliers to prevent dataloss

# %%
#craeting a histogram function
def histogram(data_frame,feature_name):
    plt.figure(figsize=(10,6))
    sns.set(style = "whitegrid")
    sns.distplot(data_frame[feature_name],kde=True)

# %%
#function to apply IQR
#Also there can be no negative value so the lower bridge is replaced with 25th percentile for the number =<0
def outlier_IQR(data_frame,feature_name):
    histogram(data_frame,feature_name)
    IQR = data_frame[feature_name].quantile(0.75)-data_frame[feature_name].quantile(0.25)
    lower_bridge = data_frame[feature_name].quantile(0.25)
    upper_bridge = data_frame[feature_name].quantile(0.75)+(IQR*1.5)
    df.loc[data_frame[feature_name]>=upper_bridge,feature_name]=upper_bridge
    df.loc[data_frame[feature_name]<=0,feature_name]=lower_bridge
    histogram(data_frame,feature_name)

# %%
outlier_IQR(df,"E")

# %%
outlier_IQR(df,"SV")

# %%
outlier_IQR(df,"SHO")

# %%
outlier_IQR(df,"R")

# %%
outlier_IQR(df,"ERA")

# %%
#ploting boxplot  for outliers
fig, ax=plt.subplots(ncols=2,nrows=9, figsize=(20,20))
index=0
ax=ax.flatten()
for col, value in df.items():
    if col != "type":
        sns.boxplot(value, ax=ax[index])
        index+=1
plt.tight_layout(pad=0.5,w_pad=0.7,h_pad=5.0)

# %%
#no ouliers can be sen

# %%
#creating x and y
x=df.drop("W", axis=1)
x
# Out:
#          R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER      ERA  CG  \
# 0   724.00  5575  1497  300  42  139  383   973  104  641  601  3.73000   2
# 1   696.00  5467  1349  277  44  156  439  1264   70  700  653  4.07000   2
# 2   669.00  5439  1395  303  29  141  533  1157   86  640  584  3.67000  11
# 3   622.00  5533  1381  260  27  136  404  1231   68  701  643  3.98000   7
# 4   689.00  5605  1515  289  49  151  455  1259   83  803  746  4.64000   7
# 5   818.75  5509  1480  308  17  232  570  1151   88  670  609  3.80000   7
# 6   764.00  5567  1397  272  19  212  554  1227   63  698  652  4.03000   3
# 7   713.00  5485  1370  246  20  217  418  1331   44  693  646  4.05000   0
# 8   644.00  5485  1383  278  32  167  436  1310   87  642  604  3.74000   1
# 9   748.00  5640  1495  294  33  161  478  1148   71  753  694  4.31000   3
# 10  751.00  5511  1419  279  32  172  503  1233  101  733  680  4.24000   5
# ...

# %%
y=df["W"]
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 5      93
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %%
#using VIF for multicolinearity check
from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
scalar=StandardScaler()
x_scaled=scalar.fit_transform(x)
x_scaled
# Out:
# array([[ 0.75905161,  0.84773126,  1.66368512,  1.42017307,  1.04119304,
#         -0.7872986 , -1.53490242, -2.69762957,  0.91388329, -0.66623393,
#         -0.50511008, -0.50718622, -0.5398062 , -0.84415269,  1.69340239,
#         -0.44746715],
#        [ 0.20231435, -0.71109353, -0.97068076,  0.12740339,  1.23580856,
#         -0.24396668, -0.5365919 ,  0.15487844, -0.60182558,  0.16597077,
#          0.24892985,  0.25625955, -0.5398062 ,  0.22214544,  0.25683995,
#         -0.6213815 ],
#        [-0.33453945, -1.1152333 , -0.15189137,  1.58879521, -0.22380785,
#         -0.7233772 ,  1.13914361, -0.89398189,  0.11144918, -0.68033909,
#         -0.75162313, -0.64191194,  2.77264091, -0.31100362, -0.65733615,
#         -1.23008175],
#        [-1.26906272,  0.24152162, -0.40108814, -0.82812203, -0.41842337,
#         -0.8831807 , -1.16053598, -0.16860185, -0.69098493,  0.18007593,
#          0.10392217,  0.05417097,  1.3004422 , -0.57757816, -0.78793273,
#          0.68297617],
# ...

# %%
vif=pd.DataFrame()
vif["vif"]=[variance_inflation_factor(x_scaled, i) for i in range(x_scaled.shape[1])]
vif["features"]=x.columns
vif
# Out:
#             vif features
# 0      9.511740        R
# 1     13.981196       AB
# 2      7.884185        H
# 3      3.738854       2B
# 4      3.432104       3B
# 5      8.975433       HR
# 6      3.725185       BB
# 7      2.490222       SO
# 8      2.112242       SB
# 9    188.635055       RA
# 10  1984.684238       ER
# 11  1487.415416      ERA
# 12     2.928327       CG
# 13     3.524588      SHO
# 14     6.170458       SV
# 15     2.139212        E

# %%
#there are alot of columns colinear with each other
#droping multicolinear variable which is less corelated with W

# %%
#creating data freame from scaled data
x=pd.DataFrame(x_scaled, columns=x.columns)
x
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.759052  0.847731  1.663685  1.420173  1.041193 -0.787299 -1.534902
# 1   0.202314 -0.711094 -0.970681  0.127403  1.235809 -0.243967 -0.536592
# 2  -0.334539 -1.115233 -0.151891  1.588795 -0.223808 -0.723377  1.139144
# 3  -1.269063  0.241522 -0.401088 -0.828122 -0.418423 -0.883181 -1.160536
# 4   0.063130  1.280738  1.984081  0.801892  1.722347 -0.403770 -0.251360
# 5   2.643011 -0.104884  1.361089  1.869832 -1.391501  2.185047  1.798742
# 6   1.554391  0.732263 -0.116292 -0.153633 -1.196885  1.545833  1.513510
# 7   0.540333 -0.451289 -0.596886 -1.615025 -1.099578  1.705636 -0.910958
# 8  -0.831626 -0.451289 -0.365489  0.183611  0.068115  0.107601 -0.590073
# 9   1.236255  1.785913  1.628086  1.082929  0.165423 -0.084163  0.158660
# 10  1.295905 -0.076017  0.275303  0.239818  0.068115  0.267405  0.604334
# 11  0.858469 -0.826562 -0.721484  0.183611 -0.515731  2.121125  0.301276
# ...

# %%
#droping colinear columns
x.drop(["E",'HR',"AB","ER","ERA","CG","H","SV"],axis=1,inplace=True)

# %%
#checking for skwness
x.skew()
# Out:
# R      0.284282
# 2B    -0.230650
# 3B     0.129502
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# SHO    0.218030
# dtype: float64

# %%
#there is no skewed data

# %%
#importing libraries
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import  r2_score
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

# %%
#spliting train test data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30, random_state=56)
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((21, 8), (21,), (9, 8), (9,))

# %%
#creating function 
def model(name):
    model=name()
    model.fit(x_train,y_train)
    pred=model.predict(x_test)
    print('MAE:', metrics.mean_absolute_error(y_test, pred))
    print('MSE:', metrics.mean_squared_error(y_test, pred))
    print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
    
    
    print("""r2 score is:
    
    """,r2_score(y_test,pred))
    
    plt.scatter(x=y_test,y=pred)
    plt.xlabel('Y Test')
    plt.ylabel('Predicted Y')

# %%
#DecisionTreeClassifier
model(DecisionTreeRegressor)
# Out:
# MAE: 6.888888888888889
# MSE: 56.888888888888886
# RMSE: 7.542472332656507
# r2 score is:
#
#      0.20933424845573112

# %%
#the predicted and test value is not showing any relation
#the MAE and MSE is also huge

# %%
#LinearRegression
model(LinearRegression)
# Out:
# MAE: 4.097271135715321
# MSE: 28.680250737292212
# RMSE: 5.355394545436612
# r2 score is:
#
#      0.6013897889978261

# %%
#the predicted and test value is showing linear relation, however
#the MAE and MSE is huge. 
#there is some distance between predicted and test value

# %%
#RandomForestRegressor
model(RandomForestRegressor)
# Out:
# MAE: 4.332222222222222
# MSE: 31.226299999999988
# RMSE: 5.588049749241678
# r2 score is:
#
#      0.5660037234042556

# %%
#the predicted and test value is showing linear relation, however
#the MAE and MSE is huge. 
#there is some distance between predicted and test value

# %%
#ExtraTreesRegressor
model(ExtraTreesRegressor)
# Out:
# MAE: 3.8377777777777786
# MSE: 27.12884444444445
# RMSE: 5.208535729400774
# r2 score is:
#
#      0.6229518874399451

# %%
#the predicted and test value is showing linear relation, however
#the MAE and MSE is less than other model. 
#there is some distance between predicted and test value
#the r2 core is 65 perccent

# %%
#KNeighborsRegressor
model(KNeighborsRegressor)
# Out:
# MAE: 4.755555555555556
# MSE: 32.80000000000001
# RMSE: 5.727128425310542
# r2 score is:
#
#      0.5441317776252572

# %%
#the predicted and test value is showing linear relation, however
#the MAE and MSE is huge. 
#there is some distance between predicted and test value
#the accurcy is 54 percent

# %%
#SVR
model(SVR)
# Out:
# MAE: 8.648787332966386
# MSE: 102.72535006809717
# RMSE: 10.135351501950842
# r2 score is:
#
#      -0.4277202051331279

# %%
#the data is more spread in this model and r2 score is in negative

# %%
#the error is very less in Extra tree classifier
#also it is showing best r2 score among other models

# %%
#Hyper_parameter_Tuning

# %%
#setting parameter for hypertuning
parameter=param_grid = {
    'n_estimators': [10,50,100],
    'criterion': ['mse', 'mae'],
    'max_depth': [8,16,32,50],
    
    #'oob_score': [True, False],
    'max_features': ['auto','sqrt','log2']
}

# %%
#using GridSearchCV for Hyper parameter tunning
gcv=GridSearchCV(ExtraTreesRegressor(),parameter,cv=5)

# %%
gcv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesRegressor(),
#              param_grid={'criterion': ['mse', 'mae'],
#                          'max_depth': [8, 16, 32, 50],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [10, 50, 100]})

# %%
#checking best parameters
gcv.best_params_
# Out:
# {'criterion': 'mse',
#  'max_depth': 50,
#  'max_features': 'auto',
#  'n_estimators': 50}

# %%
#building final model
best_model=ExtraTreesRegressor(criterion="mse", max_depth=50, max_features="auto",n_estimators=50)
best_model.fit(x_train,y_train)
pred=best_model.predict(x_test)
print("The r2 score is: ", r2_score(y_test,pred))
# Out:
# The r2 score is:  0.7047814687714483

# %%
#savingThemodel
import joblib
joblib.dump(best_model,"Baseball.pkl")
# Out:
# ['Baseball.pkl']
